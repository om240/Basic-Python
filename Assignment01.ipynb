# %% [markdown]
# Q.1 What is Python, and why is it popular?

# %% [markdown]
# a versatile, high-level programming language known for its readability and ease of use, making it popular for a wide range of applications, including web development, data science, machine learning, and automation.

# %% [markdown]
# Q.2 What is an interpreter in Python?
#
# In Python, an interpreter is a program that reads and executes Python code line by line, allowing you to see the results immediately

# %% [markdown]
# Q.3 What are pre-defined keywords in Python?
#
#   Keywords in Python are predefined reserved words with
# special meanings so the interpreter can understand them. They perform specific tasks in Python programming and are a part of its syntax.

# %% [markdown]
# Q.4 Can keywords be used as variable names?
#
# No, keywords cannot be used as variable names in programming languages

# %% [markdown]
# Q.5 What is mutability in Python?
#
# Mutability in Python refers to the ability of an object to be modified after it's created. If an object is mutable, its state or value can be changed in place, without creating a new object. This means that operations can directly alter the object's internal data or structure.

# %% [markdown]
# Q.6  Why are lists mutable, but tuples are immutable?
#
# Tuple and list data structures are very similar, but one big difference between the data types is that lists are mutable, whereas tuples are immutable. The reason for the tuple's immutability is that once the elements are added to the tuple and the tuple has been created; it remains unchanged.

# %% [markdown]
# Q.7  What is the difference between “==” and “is” operators in Python?
#
# "==" (Equality Operator): This operator compares the values of two objects. It returns True if the values are equal and False otherwise. It focuses on the content or data held by the objects.
#
# "is" (Identity Operator): This operator checks if two variables refer to the same object in memory. It returns True if they point to the same memory location and False otherwise. It focuses on whether the objects are the exact same instance.

# %% [markdown]
# Q.8 What are logical operators in Python?
#
# Logical operators in Python are used to combine or modify conditional statements. They work with boolean values (True or False) and return a boolean result. There are three main logical operators in Python: and, or, and not.

# %% [markdown]
# Q.9  What is type casting in Python?
#
# Type casting in programming refers to the process of converting a value from one data type to another. It's essentially a manual conversion that allows you to store a value of one type in a variable of a different type. This process is necessary when you need to perform operations between different data types or when you want to explicitly change the type of a variable.

# %% [markdown]
# Q.10 What is the difference between implicit and explicit type casting?
#
# 1. Implicit Type Casting:
#
# Definition: Automatic conversion of a smaller data type to a larger one.
#
# Purpose: Ensures compatibility when a smaller data type is assigned to a larger one or when different data types are combined in an expression.
#
# Safety: Generally safe as it doesn't lead to loss of data.
#
# 2. Explicit Type Casting (Narrowing):
#
# Definition: Manual conversion of a larger data type to a smaller one.
#
# Purpose: Provides control over the conversion process and can be used to prevent potential data loss or unexpected behavior.
#
# Safety: Can lead to data loss or precision issues, especially when converting from a larger floating-point type to an integer.

# %% [markdown]
# Q.11 What is the purpose of conditional statements in Python?
#
# Conditional statements in Python enable the execution of specific code blocks based on whether a condition is true or false. They are crucial for decision-making within programs, allowing for different code paths to be taken depending on the situation. The primary conditional statements in Python are if, elif, and else.

# %% [markdown]
# Q.12  How does the elif statement work?
#
# The “elif” keyword in Python, stands for “else if”. It can be used in conditional statements to check for multiple conditions. For example, if the first condition is false, it moves on to the next “elif” statement to check if that condition is true.

# %% [markdown]
# Q.13  What is the difference between for and while loops?
#
# The primary difference between for and while loops lies in when the number of iterations is known beforehand. for loops are best suited for situations where you know exactly how many times the loop will execute, often when iterating over a collection or sequence. while loops, on the other hand, are more flexible and used when the number of iterations is unknown and depends on a dynamic condition.

# %% [markdown]
# Q.14  Describe a scenario where a while loop is more suitable than a for loop.
#
# whereas a while loop is best used when you don't know the number of iterations in advance.

# %%
# Write a Python program to print "Hello, World!"
print("hello world")
# Out:
# hello world

# %%
# Write a Python program that displays your name and age
Name = "om"
Age= 17

# %%
print(Name)
print(Age)
# Out:
# om
# 17

# %%
#  Write code to print all the pre-defined keywords in Python using the keyword library
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
#  Write a program that checks if a given word is a Python keyword

# %%
 # Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each

# %%
#. Write a function to demonstrate the behavior of mutable and immutable arguments
# Out:
#   File "<ipython-input-8-35b54d6b877b>", line 2
#     def modify_data(immutable, mutable):
#                                         ^
# SyntaxError: incomplete input
